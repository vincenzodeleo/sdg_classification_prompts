# %%
import pandas as pd

# %%
# experiment_name = "2023.11.21-1_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_3-shots"
# experiment_name = "2023.11.21-2_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_5-shots"
# experiment_name = "2023.11.21-3_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_7-shots"
# experiment_name = "2023.11.22-1_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4_3-shots"
# experiment_name = "2023.11.22-2_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4_5-shots"
# experiment_name = "2023.11.22-3_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4_7-shots"
# experiment_name = "2023.11.28-1_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_3-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-2_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_5-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-3_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_7-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-4_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_3-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-5_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_5-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-6_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_7-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.12.06-01_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_3-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-02_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_5-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-03_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_7-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-04_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_3-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-05_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_5-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
experiment_name = "2023.12.06-06_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_7-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"

# %%
# !ls -l ./data/output/$experiment_name/
# Out:
# total 4420
# -rw-r--r-- 1 jovyan users   5754 Feb 18 17:12 2023.12.06-06_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_7-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES_classification_report.xlsx
# -rw-r--r-- 1 jovyan users   5777 Dec  7 07:43 gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-4-0613_classification_report.xlsx
# -rw-r--r-- 1 jovyan users 330782 Dec  7 07:43 gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-4-0613.xlsx
# -rw-r--r-- 1 jovyan users     36 Dec  6 22:29 sdg_classification_gpt-4-0613_0.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:32 sdg_classification_gpt-4-0613_1000.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:33 sdg_classification_gpt-4-0613_1001.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:33 sdg_classification_gpt-4-0613_1002.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:34 sdg_classification_gpt-4-0613_1003.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:34 sdg_classification_gpt-4-0613_1004.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:35 sdg_classification_gpt-4-0613_1005.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:35 sdg_classification_gpt-4-0613_1006.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:36 sdg_classification_gpt-4-0613_1007.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:36 sdg_classification_gpt-4-0613_1008.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:37 sdg_classification_gpt-4-0613_1009.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:32 sdg_classification_gpt-4-0613_100.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:37 sdg_classification_gpt-4-0613_1010.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:38 sdg_classification_gpt-4-0613_1011.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:38 sdg_classification_gpt-4-0613_1012.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:39 sdg_classification_gpt-4-0613_1013.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:39 sdg_classification_gpt-4-0613_1014.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:40 sdg_classification_gpt-4-0613_1015.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:40 sdg_classification_gpt-4-0613_1016.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:41 sdg_classification_gpt-4-0613_1017.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:41 sdg_classification_gpt-4-0613_1018.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:42 sdg_classification_gpt-4-0613_1019.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:32 sdg_classification_gpt-4-0613_101.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:33 sdg_classification_gpt-4-0613_102.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:33 sdg_classification_gpt-4-0613_103.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:34 sdg_classification_gpt-4-0613_104.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:34 sdg_classification_gpt-4-0613_105.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:35 sdg_classification_gpt-4-0613_106.pkl
# -rw-r--r-- 1 jovyan users     35 Dec  6 23:35 sdg_classification_gpt-4-0613_107.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  6 23:36 sdg_classification_gpt-4-0613_108.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:36 sdg_classification_gpt-4-0613_109.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 22:35 sdg_classification_gpt-4-0613_10.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:37 sdg_classification_gpt-4-0613_110.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:37 sdg_classification_gpt-4-0613_111.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  6 23:38 sdg_classification_gpt-4-0613_112.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:38 sdg_classification_gpt-4-0613_113.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:39 sdg_classification_gpt-4-0613_114.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23
pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:12 sdg_classification_gpt-4-0613_962.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:13 sdg_classification_gpt-4-0613_963.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:13 sdg_classification_gpt-4-0613_964.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:14 sdg_classification_gpt-4-0613_965.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:14 sdg_classification_gpt-4-0613_966.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:15 sdg_classification_gpt-4-0613_967.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:15 sdg_classification_gpt-4-0613_968.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:16 sdg_classification_gpt-4-0613_969.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:30 sdg_classification_gpt-4-0613_96.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:16 sdg_classification_gpt-4-0613_970.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:17 sdg_classification_gpt-4-0613_971.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:17 sdg_classification_gpt-4-0613_972.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:18 sdg_classification_gpt-4-0613_973.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:18 sdg_classification_gpt-4-0613_974.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:19 sdg_classification_gpt-4-0613_975.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:19 sdg_classification_gpt-4-0613_976.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:20 sdg_classification_gpt-4-0613_977.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:20 sdg_classification_gpt-4-0613_978.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:21 sdg_classification_gpt-4-0613_979.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  6 23:30 sdg_classification_gpt-4-0613_97.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:22 sdg_classification_gpt-4-0613_980.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:22 sdg_classification_gpt-4-0613_981.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:23 sdg_classification_gpt-4-0613_982.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:23 sdg_classification_gpt-4-0613_983.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:24 sdg_classification_gpt-4-0613_984.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:24 sdg_classification_gpt-4-0613_985.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:25 sdg_classification_gpt-4-0613_986.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:25 sdg_classification_gpt-4-0613_987.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:26 sdg_classification_gpt-4-0613_988.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:26 sdg_classification_gpt-4-0613_989.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:31 sdg_classification_gpt-4-0613_98.pkl
# -rw-r--r-- 1 jovyan users     40 Dec  7 07:27 sdg_classification_gpt-4-0613_990.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:27 sdg_classification_gpt-4-0613_991.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:28 sdg_classification_gpt-4-0613_992.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:28 sdg_classification_gpt-4-0613_993.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:29 sdg_classification_gpt-4-0613_994.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:29 sdg_classification_gpt-4-0613_995.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:30 sdg_classification_gpt-4-0613_996.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:31 sdg_classification_gpt-4-0613_997.pkl
# -rw-r--r-- 1 jovyan users     38 Dec  7 07:31 sdg_classification_gpt-4-0613_998.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  7 07:32 sdg_classification_gpt-4-0613_999.pkl
# -rw-r--r-- 1 jovyan users     36 Dec  6 23:31 sdg_classification_gpt-4-0613_99.pkl
# -rw-r--r-- 1 jovyan users     37 Dec  6 22:34 sdg_classification_gpt-4-0613_9.pkl

# %%
data = pd.read_excel("../data/input/sdg_17_labels_classification_dataset_1020_texts_TEST.xlsx").drop(columns=['Unnamed: 0'])

# %%
output_datapath = f"./data/output/{experiment_name}/"

# %%
# results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_13B.xlsx')
try:
    results_processed_merged = pd.read_excel(output_datapath+'gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-3.5-turbo-0301.xlsx')
except:
    results_processed_merged = pd.read_excel(output_datapath+'gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-4-0613.xlsx')

# %%
results_processed_merged.head(3)
# Out:
#    Unnamed: 0  text_id  doi  \
# 0           0     6668  NaN
# 1           1     6099  NaN
# 2           2     6471  NaN
#
#                                                 text  sdg  labels_negative  \
# 0  L train resumes service after derailing from t...    0              NaN
# 1  Brooklyn Decker’s SI Swimsuit Cover Photo Shoo...    0              NaN
# 2  Mumbai: The Bombay High Court has suspended th...    0              NaN
#
#    labels_positive  agreement  cnt        result  label_pred
# 0              NaN        NaN    0   ---SDG 0---         0.0
# 1              NaN        NaN    1   ---SDG 0---         0.0
# 2              NaN        NaN    2  ---SDG 16---        16.0

# %%
results_processed_merged = results_processed_merged.rename(columns={'label_pred': 'predicted_label_clean'})

# %%
results_processed_merged = results_processed_merged[~results_processed_merged.predicted_label_clean.isna()]

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = results_processed_merged.sdg 
y_pred = results_processed_merged.predicted_label_clean
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred)) #, target_names=target_names))
# Out:
# 1016
# 1016
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        60
#            1       0.75      0.82      0.78        60
#            2       0.98      0.86      0.92        59
#            3       0.76      0.97      0.85        60
#            4       0.83      0.97      0.89        60
#            5       0.93      0.83      0.88        60
#            6       0.98      0.93      0.96        60
#            7       0.95      0.87      0.90        60
#            8       0.62      0.78      0.69        59
#            9       0.74      0.82      0.78        60
#           10       0.73      0.61      0.67        59
#           11       0.85      0.88      0.87        60
#           12       0.88      0.85      0.86        60
#           13       0.79      0.90      0.84        60
#           14       0.97      0.97      0.97        60
#           15       0.89      0.92      0.90        59
#           16       0.89      0.80      0.84        60
#           17       0.00      0.00      0.00         0
#
#     accuracy                           0.84      1016
#    macro avg       0.81      0.80      0.80      1016
# weighted avg       0.86      0.84      0.84      1016
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
try:
    results_processed_merged = pd.read_excel(output_datapath+'gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-3.5-turbo-0301.xlsx')
except:
    results_processed_merged = pd.read_excel(output_datapath+'gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-4-0613.xlsx')

# %%
results_processed_merged.head(3)
# Out:
#    Unnamed: 0  text_id  doi  \
# 0           0     6668  NaN
# 1           1     6099  NaN
# 2           2     6471  NaN
#
#                                                 text  sdg  labels_negative  \
# 0  L train resumes service after derailing from t...    0              NaN
# 1  Brooklyn Decker’s SI Swimsuit Cover Photo Shoo...    0              NaN
# 2  Mumbai: The Bombay High Court has suspended th...    0              NaN
#
#    labels_positive  agreement  cnt        result  label_pred
# 0              NaN        NaN    0   ---SDG 0---         0.0
# 1              NaN        NaN    1   ---SDG 0---         0.0
# 2              NaN        NaN    2  ---SDG 16---        16.0

# %%
results_processed_merged.shape[0]
# Out:
# 1020

# %%
results_processed_merged = results_processed_merged.rename(columns={'label_pred':'predicted_label_clean'})

# %%
# SE IN results_processed_merged MANCANO RIGHE ALLORA LE AGGIUNGO 
# CARICANDOLE DA data PER POI ASSEGNARE A QUESTE UNA LABEL DIVERSA
# DA QUELLA ATTESA

import numpy

data['predicted_label_clean'] = 99

# Effettua una fusione (merge) basata sulla colonna "text_id"
merged_df = pd.merge(results_processed_merged, data, on='text_id', how='outer', indicator=True)
merged_df['sdg'] = merged_df['sdg_y']

# Seleziona solo le righe presenti in data ma non in results_processed_merged
new_rows = merged_df[merged_df['_merge'] == 'right_only'].drop('_merge', axis=1)

# Aggiungi le nuove righe a "results_processed_merged"
results_processed_merged = pd.concat([results_processed_merged, new_rows], ignore_index=True)

# %%
# merged_df[merged_df.text_id==1250]

# %%
# # results_processed_merged['predicted_label_clean'] = results_processed_merged.predicted_label_clean.apply(lambda x: 0 if x>16 else x)

# # CORREZIONI NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI O OUTPUT NON UTILI PER DEFINIRE LA CLASSE O CLASSI NON PREVISTE 

# import random

# # NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI SELEZIONO SEMPRE IL PRIMO
# results_processed_merged = results_processed_merged.drop_duplicates(subset='text_id', keep='first')

# # Lista di valori sdg_list
# # sdg_list = [str(x) for x in range(17)]
# sdg_list = [x for x in range(17)]
# # print(sdg_list)

# # Se il valore di 'predicted_label_clean' e' NaN o un valore numerico non presente nella lista sdg_list 
# # allora assegna a  'predicted_label_clean' un valore qualunque estratto a caso da sdg_list ma diverso dal valore di 'sdg' per la riga in esame
# # Modifica della colonna 'predicted_label_clean' secondo le regole specificate
# for index, row in results_processed_merged.iterrows():
#     if pd.isna(row['predicted_label_clean']) or row['predicted_label_clean'] not in sdg_list:
#         new_value = random.choice([x for x in sdg_list if x != row['sdg']])
#         results_processed_merged.at[index, 'predicted_label_clean'] = new_value

# %%
# results_processed_merged['predicted_label_clean'] = results_processed_merged.predicted_label_clean.apply(lambda x: 0 if x>16 else x)

# CORREZIONI NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI O OUTPUT NON UTILI PER DEFINIRE LA CLASSE O CLASSI NON PREVISTE 

# NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI SELEZIONO SEMPRE IL PRIMO
results_processed_merged = results_processed_merged.drop_duplicates(subset='text_id', keep='first')

# Lista di valori sdg_list
# sdg_list = [str(x) for x in range(17)]
sdg_list = [x for x in range(17)]
# print(sdg_list)

# Se il valore di 'predicted_label_clean' e' NaN o un valore numerico non presente nella lista sdg_list 
# allora assegna a  'predicted_label_clean' il valore 0 (Other)
for index, row in results_processed_merged.iterrows():
    if pd.isna(row['predicted_label_clean']) or row['predicted_label_clean'] not in sdg_list:
        results_processed_merged.at[index, 'predicted_label_clean'] = 0

# %%
results_processed_merged.shape[0]
# Out:
# 1020

# %%
results_processed_merged[['text_id', 'sdg', 'predicted_label_clean']]
# Out:
#       text_id  sdg  predicted_label_clean
# 0        6668    0                    0.0
# 1        6099    0                    0.0
# 2        6471    0                   16.0
# 3        1786    0                    9.0
# 4        2143    0                    7.0
# ...       ...  ...                    ...
# 1015     4695   16                   16.0
# 1016     6628   16                   16.0
# 1017     4563   16                   16.0
# 1018     6710   16                   16.0
# 1019     1947   16                   16.0
#
# [1020 rows x 3 columns]

# %%
# data[data.text_id==1250]

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = results_processed_merged.sdg 
y_pred = results_processed_merged.predicted_label_clean
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred)) #, target_names=target_names))
# Out:
# 1020
# 1020
#               precision    recall  f1-score   support
#
#            0       0.85      0.55      0.67        60
#            1       0.75      0.82      0.78        60
#            2       0.98      0.85      0.91        60
#            3       0.76      0.97      0.85        60
#            4       0.83      0.97      0.89        60
#            5       0.93      0.83      0.88        60
#            6       0.98      0.93      0.96        60
#            7       0.95      0.87      0.90        60
#            8       0.62      0.77      0.69        60
#            9       0.74      0.82      0.78        60
#           10       0.73      0.60      0.66        60
#           11       0.85      0.88      0.87        60
#           12       0.88      0.85      0.86        60
#           13       0.79      0.90      0.84        60
#           14       0.97      0.97      0.97        60
#           15       0.89      0.90      0.89        60
#           16       0.89      0.80      0.84        60
#
#     accuracy                           0.84      1020
#    macro avg       0.85      0.84      0.84      1020
# weighted avg       0.85      0.84      0.84      1020

# %%
# from io import StringIO

# classification_report_str = classification_report(y_true, y_pred, digits=3)
# df = pd.read_csv(StringIO(classification_report_str), sep='\s+', engine='python')
# df[['precision', 'recall', 'f1-score']] *= 100
# df

# %%
classification_report_filename = output_datapath+f'/{experiment_name}_classification_report.xlsx'
classification_report_filename

report=classification_report(y_true, y_pred, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df[['precision', 'recall', 'f1-score']] *= 100
report_df.to_excel(classification_report_filename)

# %%
report_df
# Out:
#               precision     recall   f1-score      support
# 0             84.615385  55.000000  66.666667    60.000000
# 1             75.384615  81.666667  78.400000    60.000000
# 2             98.076923  85.000000  91.071429    60.000000
# 3             76.315789  96.666667  85.294118    60.000000
# 4             82.857143  96.666667  89.230769    60.000000
# 5             92.592593  83.333333  87.719298    60.000000
# 6             98.245614  93.333333  95.726496    60.000000
# 7             94.545455  86.666667  90.434783    60.000000
# 8             62.162162  76.666667  68.656716    60.000000
# 9             74.242424  81.666667  77.777778    60.000000
# 10            73.469388  60.000000  66.055046    60.000000
# 11            85.483871  88.333333  86.885246    60.000000
# 12            87.931034  85.000000  86.440678    60.000000
# 13            79.411765  90.000000  84.375000    60.000000
# 14            96.666667  96.666667  96.666667    60.000000
# 15            88.524590  90.000000  89.256198    60.000000
# 16            88.888889  80.000000  84.210526    60.000000
# accuracy      83.921569  83.921569  83.921569     0.839216
# macro avg     84.671430  83.921569  83.815730  1020.000000
# weighted avg  84.671430  83.921569  83.815730  1020.000000

# %%
if y_true.shape[0]!=1020:
    raise Exception("ERROR!!!!")

# %%
accuracy = report_df.loc['accuracy']['precision']
precision = report_df.loc['macro avg']['precision']
recall = report_df.loc['macro avg']['recall']
f1_score = report_df.loc['macro avg']['f1-score']

# %%
print(precision, recall, accuracy, f1_score)
# Out:
# 84.67142980096743 83.92156862745098 83.92156862745098 83.81573023301654

# %%
print(round(precision, 1), round(recall, 1), round(accuracy, 1), round(f1_score, 1))
# Out:
# 84.7 83.9 83.9 83.8
