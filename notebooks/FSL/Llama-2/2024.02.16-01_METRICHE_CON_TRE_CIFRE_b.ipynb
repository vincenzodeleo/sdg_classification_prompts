# %%
# experiment_name, SDG_dir, model_dir = "2023.11.21-1_LLama2_7B-chat-hf_4-bit_float-16_3-few-shot", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.11.21-3_LLama2_7B-chat-hf_4-bit_float-16_7-few-shot", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.11.21-4_LLama2_13B-chat-hf_4-bit_float-16_3-few-shot", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.11.28-3_LLama2_13B-chat-hf_4-bit_float-16_5-few-shot_SEMANTIC_SIMILARITY", "SDG", "Llama-2" #"2024.01.03-02_LLama2_13B-chat-hf_4-bit_float-16_5-few-shot_SEMANTIC_SIMILARITY---DEBUG_ERRORI"
# experiment_name, SDG_dir, model_dir = "2023.11.28-4_LLama2_7B-chat-hf_4-bit_float-16_7-few-shot_SEMANTIC_SIMILARITY", "SDG_provavincenzo400", "Llama-2" # --> SDG_provavincenzo400
# experiment_name, SDG_dir, model_dir = "2023.12.06-1_LLama2_7B-chat-hf_4-bit_float-16_3-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.12.06-2_LLama2_7B-chat-hf_4-bit_float-16_5-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.12.06-03_LLama2_7B-chat-hf_4-bit_float-16_7-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.12.06-04_LLama2_13B-chat-hf_4-bit_float-16_3-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.12.06-05_LLama2_13B-chat-hf_4-bit_float-16_5-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES", "SDG", "Llama-2"
# experiment_name, SDG_dir, model_dir = "2023.12.12-01_LLama2_13B-chat-hf_4-bit_float-16_7-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES_SDG0_TAGLIATO", "SDG", "Llama-2"

#experiment_name, SDG_dir, model_dir = "2024.02.15-01_LLama2_13B-chat-hf_4-bit_float-16_zero-shot_RIESECUZIONE_PER_VERIFICA_FINALE_PAPER", "SDG", "Llama-2"

# experiment_name, SDG_dir, model_dir = "2023.12.14-02_LLama2_7B-chat-hf_4-bit_float-16_zero-shot_FINETUNED", "SDG", "Llama-2_FineTuning"
# experiment_name, SDG_dir, model_dir = "2023.12.12-04_LLama2_7B-chat-hf_NON-4-bit_float-16_zero-shot_FINETUNED", "SDG", "Llama-2_FineTuning"
experiment_name, SDG_dir, model_dir = "2023.12.13-01_LLama2_13B-chat-hf_4-bit_float-16_zero-shot_FINETUNED", "SDG", "Llama-2_FineTuning"

# experiment_name, SDG_dir, model_dir = "", "SDG", "Flan-T5_FineTuning"

# %%
import pandas as pd
import pickle
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
from IPython.display import Image, display

mount_point = "/content/gdrive"
base_path = mount_point + f"/MyDrive/Colab/{SDG_dir}/data"
input_data_path = base_path + "/input/sdg_17_labels_classification_dataset_1020_texts_TEST_2023.12.11.xlsx"
input_data_path_train = base_path + "/input/sdg_17_labels_classification_dataset_4760_texts_TRAIN_2023.12.11.xlsx"

output_data_path = base_path + f"/../{model_dir}/data/output/{experiment_name}"

drive.mount(mount_point, force_remount=True)
# data_path = '/content/gdrive/MyDrive/Colab/SDG/Data/input/2023.10.17-1_GPT_zero-shot-learning_all-17-sdg.xlsx'
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/MyDrive/Colab/$SDG_dir/$model_dir/data/output/$experiment_name | head -5
# Out:
# 2023.12.13-01_LLama2_13B-chat-hf_4-bit_float-16_zero-shot_FINETUNED_classification_report.xlsx
# 2023.12.13-01_LLama2_13B-chat-hf_4-bit_float-16_zero-shot_FINETUNED.xlsx
# sdg_classification_Llama2_13B_SEMANTIC_SIMILARITY_0.pkl
# sdg_classification_Llama2_13B_SEMANTIC_SIMILARITY_1000.pkl
# sdg_classification_Llama2_13B_SEMANTIC_SIMILARITY_1001.pkl

# %%
nbit = 4
llamasize = '7B'
# llamasize = '13B'
temp = 0.1

# %%
data = pd.read_excel(input_data_path)
data.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  text_id  doi  \
# 0             0           0     6668  NaN
# 1             1           1     6099  NaN
# 2             2           2     6471  NaN
#
#                                                 text  sdg  labels_negative  \
# 0  L train resumes service after derailing from t...    0              NaN
# 1  Brooklyn Decker’s SI Swimsuit Cover Photo Shoo...    0              NaN
# 2  Mumbai: The Bombay High Court has suspended th...    0              NaN
#
#    labels_positive  agreement  text_length
# 0              NaN        NaN           38
# 1              NaN        NaN           15
# 2              NaN        NaN          125

# %%
data_sel = data

# %%
# res_filename = "2023.11.21-3_LLama2_7B-chat-hf_4-bit_float-16_7-few-shot.xlsx"
# res_filename = "2023.11.28-3_LLama2_13B-chat-hf_4-bit_float-16_5-few-shot_SEMANTIC_SIMILARITY.xlsx"
res_filename = experiment_name+".xlsx"
# res_filename = "2023.12.12-04_LLama2_7B-chat-hf_4-bit_float-16_zero-shot_FINETUNED.xlsx"
# final = pd.read_excel(output_data_path+"/2023.11.21-1_LLama2_7B-chat-hf_4-bit_float-16_3-few-shot.xlsx")
final = pd.read_excel(output_data_path+"/"+res_filename)
final.head(3)
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  text_id  doi  \
# 0             0             0           0     6668  NaN
# 1             1             1           1     6099  NaN
# 2             2             2           2     6471  NaN
#
#                                                 text  sdg  labels_negative  \
# 0  L train resumes service after derailing from t...    0              NaN
# 1  Brooklyn Decker’s SI Swimsuit Cover Photo Shoo...    0              NaN
# 2  Mumbai: The Bombay High Court has suspended th...    0              NaN
#
#    labels_positive  agreement  text_length  cnt  sdg_true         result  \
# 0              NaN        NaN           38    0         0   ---SDG 0---
# 1              NaN        NaN           15    1         0   ---SDG 0---
# 2              NaN        NaN          125    2         0  ---SDG 16---
#
#    label
# 0      0
# 1      0
# 2     16

# %%
final.shape[0]
# Out:
# 1020

# %%
final = final[~final.label.isna()]

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = final.sdg
y_pred = final.label
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred)) #, target_names=target_names))
# Out:
# 1020
# 1020
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        60
#            1       0.90      0.62      0.73        60
#            2       0.92      0.90      0.91        60
#            3       0.87      0.97      0.91        60
#            4       0.88      0.93      0.90        60
#            5       0.93      0.87      0.90        60
#            6       0.95      0.95      0.95        60
#            7       0.86      0.92      0.89        60
#            8       0.56      0.68      0.62        60
#            9       0.72      0.90      0.80        60
#           10       0.65      0.65      0.65        60
#           11       0.89      0.85      0.87        60
#           12       0.96      0.85      0.90        60
#           13       0.83      0.87      0.85        60
#           14       0.92      0.97      0.94        60
#           15       0.95      0.92      0.93        60
# ...

# %%
final = pd.read_excel(output_data_path+"/"+res_filename)

# %%
final.shape[0]
# Out:
# 1020

# %%
try:
  final['text_id'] = final['text_id_x']
except:
  pass

# %%
results_processed_merged = final
results_processed_merged = results_processed_merged.rename(columns={'label':'predicted_label_clean'})

# %%
# CORREZIONI NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI O OUTPUT NON UTILI PER DEFINIRE LA CLASSE O CLASSI NON PREVISTE

import random

# NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI SELEZIONO SEMPRE IL PRIMO
results_processed_merged = results_processed_merged.drop_duplicates(subset='text_id', keep='first')

# # NEL CASO IN CUI IL MODELLO RESTITUISCA OUTPUT NON UTILI PER DEFINIRE LA CLASSE SI APPLICA LA CLASSE 0
# # results_processed_merged.loc[results_processed_merged['predicted_label_clean'].isna(), 'predicted_label_clean'] = 0
# results_processed_merged.loc[results_processed_merged['predicted_label_clean'].isna(), 'predicted_label_clean'] = results_processed_merged.loc[results_processed_merged['predicted_label_clean'].isna(), 'sdg'] - 1

# # NEL CASO IN CUI IL MODELLO RESTITUISCA CLASSI NON PREVISTE SI APPLICA LA CLASSE 0
# results_processed_merged['predicted_label_clean'] = results_processed_merged.predicted_label_clean.apply(lambda x: 0 if int(x)>16 else x)

# Lista di valori sdg_list
# sdg_list = [str(x) for x in range(17)]
sdg_list = [x for x in range(17)]
# print(sdg_list)

# Se il valore di 'predicted_label_clean' e' NaN o un valore numerico non presente nella lista sdg_list
# allora assegna a  'predicted_label_clean' un valore qualunque estratto a caso da sdg_list ma diverso dal valore di 'sdg' per la riga in esame
# Modifica della colonna 'predicted_label_clean' secondo le regole specificate
for index, row in results_processed_merged.iterrows():
    if pd.isna(row['predicted_label_clean']) or row['predicted_label_clean'] not in sdg_list:
        # new_value = random.choice([x for x in sdg_list if x != row['sdg']])
        results_processed_merged.at[index, 'predicted_label_clean'] = 0 #new_value

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = results_processed_merged.sdg
y_pred = results_processed_merged.predicted_label_clean
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred)) #, target_names=target_names))
# Out:
# 1020
# 1020
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        60
#            1       0.90      0.62      0.73        60
#            2       0.92      0.90      0.91        60
#            3       0.87      0.97      0.91        60
#            4       0.88      0.93      0.90        60
#            5       0.93      0.87      0.90        60
#            6       0.95      0.95      0.95        60
#            7       0.86      0.92      0.89        60
#            8       0.56      0.68      0.62        60
#            9       0.72      0.90      0.80        60
#           10       0.65      0.65      0.65        60
#           11       0.89      0.85      0.87        60
#           12       0.96      0.85      0.90        60
#           13       0.83      0.87      0.85        60
#           14       0.92      0.97      0.94        60
#           15       0.95      0.92      0.93        60
# ...

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = results_processed_merged.sdg
y_pred = results_processed_merged.predicted_label_clean
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred, digits=4)) #, target_names=target_names))
# Out:
# 1020
# 1020
#               precision    recall  f1-score   support
#
#            0     1.0000    0.8667    0.9286        60
#            1     0.9024    0.6167    0.7327        60
#            2     0.9153    0.9000    0.9076        60
#            3     0.8657    0.9667    0.9134        60
#            4     0.8750    0.9333    0.9032        60
#            5     0.9286    0.8667    0.8966        60
#            6     0.9500    0.9500    0.9500        60
#            7     0.8594    0.9167    0.8871        60
#            8     0.5616    0.6833    0.6165        60
#            9     0.7200    0.9000    0.8000        60
#           10     0.6500    0.6500    0.6500        60
#           11     0.8947    0.8500    0.8718        60
#           12     0.9623    0.8500    0.9027        60
#           13     0.8254    0.8667    0.8455        60
#           14     0.9206    0.9667    0.9431        60
#           15     0.9483    0.9167    0.9322        60
# ...

# %%
report=classification_report(y_true, y_pred, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df[['precision', 'recall', 'f1-score']] *= 100
# report_df.to_excel(classification_report_filename)

# %%
report_df
# Out:
#                precision     recall   f1-score      support
# 0             100.000000  86.666667  92.857143    60.000000
# 1              90.243902  61.666667  73.267327    60.000000
# 2              91.525424  90.000000  90.756303    60.000000
# 3              86.567164  96.666667  91.338583    60.000000
# 4              87.500000  93.333333  90.322581    60.000000
# 5              92.857143  86.666667  89.655172    60.000000
# 6              95.000000  95.000000  95.000000    60.000000
# 7              85.937500  91.666667  88.709677    60.000000
# 8              56.164384  68.333333  61.654135    60.000000
# 9              72.000000  90.000000  80.000000    60.000000
# 10             65.000000  65.000000  65.000000    60.000000
# 11             89.473684  85.000000  87.179487    60.000000
# 12             96.226415  85.000000  90.265487    60.000000
# 13             82.539683  86.666667  84.552846    60.000000
# 14             92.063492  96.666667  94.308943    60.000000
# ...

# %%
accuracy = report_df.loc['accuracy']['precision']
precision = report_df.loc['macro avg']['precision']
recall = report_df.loc['macro avg']['recall']
f1_score = report_df.loc['macro avg']['f1-score']

# %%
print(precision, recall, accuracy, f1_score)
# Out:
# 86.50903821223172 85.58823529411764 85.58823529411764 85.69315731086151

# %%
print(round(precision, 1), round(recall, 1), round(accuracy, 1), round(f1_score, 1))
# Out:
# 86.5 85.6 85.6 85.7
