# %%
import pandas as pd

# %%
# experiment_name = "2023.11.21-1_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_3-shots"
# experiment_name = "2023.11.21-2_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_5-shots"
# experiment_name = "2023.11.21-3_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_7-shots"
# experiment_name = "2023.11.22-1_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4_3-shots"
# experiment_name = "2023.11.22-2_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4_5-shots"
# experiment_name = "2023.11.22-3_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4_7-shots"
# experiment_name = "2023.11.28-1_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_3-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-2_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_5-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-3_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_7-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-4_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_3-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-5_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_5-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.11.28-6_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_7-shots_SEMANTIC-SIMILARITY"
# experiment_name = "2023.12.06-01_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_3-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-02_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_5-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-03_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT3.5_7-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-04_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_3-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-05_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_5-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-06_GPT_few-shot-learning_all-17-sdg_1020-texts_GPT4.0_7-shots_SEMANTIC-SIMILARITY_WITH_DIFFERENT_CLASSES"

# experiment_name = "2023.11.15-1_Llama2_7B_API"
# experiment_name = "2023.11.15-2_Llama2_13B_API"
# experiment_name = "2023.11.16-1_Llama2_70B_API"
# experiment_name = "2023.11.21-1_Llama2_7B_API_3-few-shot"
# experiment_name = "2023.11.21-2_Llama2_7B_API_5-few-shot"
# experiment_name = "2023.11.21-3_Llama2_7B_API_7-few-shot"
# experiment_name = "2023.11.21-4_Llama2_13B_API_3-few-shot"
# experiment_name = "2023.11.21-5_Llama2_13B_API_5-few-shot"
# experiment_name = "2023.11.22-1_Llama2_13B_API_7-few-shot"
# experiment_name = "2023.11.28-10_Llama2_70B_API_3-few-shot"
# experiment_name = "2023.11.28-11_Llama2_70B_API_5-few-shot"
# experiment_name = "2023.11.28-12_Llama2_70B_API_7-few-shot"
# experiment_name = "2023.11.28-1_Llama2_7B_API_3-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-2_Llama2_7B_API_5-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-3_Llama2_7B_API_7-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-4_Llama2_13B_API_3-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-5_Llama2_13B_API_5-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-6_Llama2_13B_API_7-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-7_Llama2_70B_API_3-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-8_Llama2_70B_API_5-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.11.28-9_Llama2_70B_API_7-few-shot_SEMANTIC_SIMILARITY"
# experiment_name = "2023.12.06-01_Llama2_7B_API_3-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-02_Llama2_7B_API_5-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-03_Llama2_7B_API_7-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-04_Llama2_13B_API_3-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-05_Llama2_13B_API_5-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-06_Llama2_13B_API_7-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-07_Llama2_70B_API_3-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
# experiment_name = "2023.12.06-08_Llama2_70B_API_5-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"
experiment_name = "2023.12.06-09_Llama2_70B_API_7-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES"

# %%
# !ls -l ./data/output/$experiment_name/
# Out:
# total 4420
# -rw-r--r-- 1 jovyan users   5819 Feb 16 14:30 2023.12.06-09_Llama2_70B_API_7-few-shot_SEMANTIC_SIMILARITY_WITH_DIFFERENT_CLASSES_classification_report.xlsx
# -rw-r--r-- 1 jovyan users 338314 Dec  6 13:46 report_sdg_classification_Llama2_7B.xlsx
# -rw-r--r-- 1 jovyan users    371 Dec  6 13:30 sdg_classification_Llama2_70B_SEMANTIC_SIMILARITY_0.pkl
# -rw-r--r-- 1 jovyan users    372 Dec  6 13:45 sdg_classification_Llama2_70B_SEMANTIC_SIMILARITY_1000.pkl
# -rw-r--r-- 1 jovyan users    373 Dec  6 13:45 sdg_classification_Llama2_70B_SEMANTIC_SIMILARITY_1001.pkl
# -rw-r--r-- 1 jovyan users    373 Dec  6 13:45 sdg_classification_Llama2_70B_SEMANTIC_SIMILARITY_1002.pkl
# -rw-r--r-- 1 jovyan users    373 Dec  6 13:45 sdg_classification_Llama2_70B_SEMANTIC_SIMILARITY_1003.pkl
# -rw-r--r-- 1 jovyan users    372 Dec  6 13:45 sdg_classification_Llama2_70B_SEMANTIC_SIMILARITY_1004.pkl
# ...

# %%
data = pd.read_excel("../data/input/sdg_17_labels_classification_dataset_1020_texts_TEST.xlsx").drop(columns=['Unnamed: 0'])

# %%
output_datapath = f"./data/output/{experiment_name}/"

# %%
# results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_13B.xlsx')
# results_processed_merged = pd.read_excel(output_datapath+'gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-3.5-turbo-0301.xlsx')
# results_processed_merged = pd.read_excel(output_datapath+'gpt_1000_texts_17sdg_temperature_0.0_model_name_gpt-4-0613.xlsx')
try:
    results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_7B.xlsx')
except:
    try:
        results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_13B.xlsx')
    except:
        results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_70B.xlsx')

# %%
results_processed_merged.head(3)
# Out:
#    Unnamed: 0  text_id  doi  \
# 0           0     6668  NaN
# 1           1     6099  NaN
# 2           2     6471  NaN
#
#                                                 text  sdg  labels_negative  \
# 0  L train resumes service after derailing from t...    0              NaN
# 1  Brooklyn Decker’s SI Swimsuit Cover Photo Shoo...    0              NaN
# 2  Mumbai: The Bombay High Court has suspended th...    0              NaN
#
#    labels_positive  agreement  cnt    id  true_label predicted_label  \
# 0              NaN        NaN    0  6668           0     ---SDG 0---
# 1              NaN        NaN    1  6099           0    ---SDG 11---
# 2              NaN        NaN    2  6471           0    ---SDG 16---
#
#    predicted_label_clean
# 0                      0
# 1                     11
# 2                     16

# %%
#results_processed_merged = results_processed_merged.rename(columns={'label_pred': 'predicted_label_clean'})

# %%
results_processed_merged = results_processed_merged[~results_processed_merged.predicted_label_clean.isna()]

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = results_processed_merged.sdg 
y_pred = results_processed_merged.predicted_label_clean
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred)) #, target_names=target_names))
# Out:
# 1014
# 1014
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29        59
#            1       0.79      0.63      0.70        60
#            2       0.87      0.88      0.88        60
#            3       0.72      0.97      0.83        60
#            4       0.76      0.97      0.85        60
#            5       0.88      0.72      0.79        60
#            6       0.98      0.93      0.95        57
#            7       0.94      0.76      0.84        59
#            8       0.49      0.78      0.60        60
#            9       0.74      0.70      0.72        60
#           10       0.60      0.62      0.61        60
#           11       0.71      0.92      0.80        60
#           12       0.84      0.78      0.81        60
#           13       0.84      0.80      0.82        60
#           14       0.93      0.87      0.90        60
#           15       0.87      0.88      0.88        60
# ...

# %%
# tryresults_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_7B.xlsx')
# results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_13B.xlsx')
# results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_70B.xlsx')

try:
    results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_7B.xlsx')
except:
    try:
        results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_13B.xlsx')
    except:
        results_processed_merged = pd.read_excel(output_datapath+'report_sdg_classification_Llama2_70B.xlsx')

# %%
results_processed_merged.head(3)
# Out:
#    Unnamed: 0  text_id  doi  \
# 0           0     6668  NaN
# 1           1     6099  NaN
# 2           2     6471  NaN
#
#                                                 text  sdg  labels_negative  \
# 0  L train resumes service after derailing from t...    0              NaN
# 1  Brooklyn Decker’s SI Swimsuit Cover Photo Shoo...    0              NaN
# 2  Mumbai: The Bombay High Court has suspended th...    0              NaN
#
#    labels_positive  agreement  cnt    id  true_label predicted_label  \
# 0              NaN        NaN    0  6668           0     ---SDG 0---
# 1              NaN        NaN    1  6099           0    ---SDG 11---
# 2              NaN        NaN    2  6471           0    ---SDG 16---
#
#    predicted_label_clean
# 0                      0
# 1                     11
# 2                     16

# %%
results_processed_merged.shape[0]
# Out:
# 1014

# %%
results_processed_merged = results_processed_merged.rename(columns={'label_pred':'predicted_label_clean'})

# %%
# SE IN results_processed_merged MANCANO RIGHE ALLORA LE AGGIUNGO 
# CARICANDOLE DA data PER POI ASSEGNARE A QUESTE UNA LABEL DIVERSA
# DA QUELLA ATTESA

import numpy

data['predicted_label_clean'] = 99

# Effettua una fusione (merge) basata sulla colonna "text_id"
merged_df = pd.merge(results_processed_merged, data, on='text_id', how='outer', indicator=True)
merged_df['sdg'] = merged_df['sdg_y']

# Seleziona solo le righe presenti in data ma non in results_processed_merged
new_rows = merged_df[merged_df['_merge'] == 'right_only'].drop('_merge', axis=1)

# Aggiungi le nuove righe a "results_processed_merged"
results_processed_merged = pd.concat([results_processed_merged, new_rows], ignore_index=True)

# %%
# results_processed_merged['predicted_label_clean'] = results_processed_merged.predicted_label_clean.apply(lambda x: 0 if x>16 else x)

# CORREZIONI NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI O OUTPUT NON UTILI PER DEFINIRE LA CLASSE O CLASSI NON PREVISTE 

import random

# NEL CASO IN CUI IL MODELLO RESTITUISCA DUPLICATI SELEZIONO SEMPRE IL PRIMO
results_processed_merged = results_processed_merged.drop_duplicates(subset='text_id', keep='first')

# Lista di valori sdg_list
# sdg_list = [str(x) for x in range(17)]
sdg_list = [x for x in range(17)]
# print(sdg_list)

# Se il valore di 'predicted_label_clean' e' NaN o un valore numerico non presente nella lista sdg_list 
# allora assegna a  'predicted_label_clean' un valore qualunque estratto a caso da sdg_list ma diverso dal valore di 'sdg' per la riga in esame
# Modifica della colonna 'predicted_label_clean' secondo le regole specificate
for index, row in results_processed_merged.iterrows():
    if pd.isna(row['predicted_label_clean']) or row['predicted_label_clean'] not in sdg_list:
#         new_value = random.choice([x for x in sdg_list if x != row['sdg']])
        results_processed_merged.at[index, 'predicted_label_clean'] = 0  # new_value

# %%
results_processed_merged.shape[0]
# Out:
# 1020

# %%
results_processed_merged[['text_id', 'sdg', 'predicted_label_clean']]
# Out:
#       text_id  sdg  predicted_label_clean
# 0        6668    0                    0.0
# 1        6099    0                   11.0
# 2        6471    0                   16.0
# 3        1786    0                    4.0
# 4        2143    0                   10.0
# ...       ...  ...                    ...
# 1015     6194    6                    0.0
# 1016     6342    6                    0.0
# 1017     6438    6                    0.0
# 1018     5922    7                    0.0
# 1019     2092   16                    0.0
#
# [1020 rows x 3 columns]

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = results_processed_merged.sdg 
y_pred = results_processed_merged.predicted_label_clean
y_true = np.array([int(label) for label in y_true])
y_pred = np.array([int(label) for label in y_pred])
print(y_true.shape[0])
print(y_pred.shape[0])
#target_names = ['sdg 0', 'sdg 1', 'sdg 2',  'sdg 3']

print(classification_report(y_true, y_pred)) #, target_names=target_names))
# Out:
# 1020
# 1020
#               precision    recall  f1-score   support
#
#            0       0.55      0.20      0.29        60
#            1       0.79      0.63      0.70        60
#            2       0.87      0.88      0.88        60
#            3       0.72      0.97      0.83        60
#            4       0.76      0.97      0.85        60
#            5       0.88      0.72      0.79        60
#            6       0.98      0.88      0.93        60
#            7       0.94      0.75      0.83        60
#            8       0.49      0.78      0.60        60
#            9       0.74      0.70      0.72        60
#           10       0.60      0.62      0.61        60
#           11       0.71      0.92      0.80        60
#           12       0.84      0.78      0.81        60
#           13       0.84      0.80      0.82        60
#           14       0.93      0.87      0.90        60
#           15       0.87      0.88      0.88        60
# ...

# %%
# from io import StringIO

# classification_report_str = classification_report(y_true, y_pred, digits=3)
# df = pd.read_csv(StringIO(classification_report_str), sep='\s+', engine='python')
# df[['precision', 'recall', 'f1-score']] *= 100
# df

# %%
classification_report_filename = output_datapath+f'/{experiment_name}_classification_report.xlsx'
classification_report_filename

report=classification_report(y_true, y_pred, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df[['precision', 'recall', 'f1-score']] *= 100
report_df.to_excel(classification_report_filename)

# %%
report_df
# Out:
#               precision     recall   f1-score      support
# 0             54.545455  20.000000  29.268293    60.000000
# 1             79.166667  63.333333  70.370370    60.000000
# 2             86.885246  88.333333  87.603306    60.000000
# 3             72.500000  96.666667  82.857143    60.000000
# 4             76.315789  96.666667  85.294118    60.000000
# 5             87.755102  71.666667  78.899083    60.000000
# 6             98.148148  88.333333  92.982456    60.000000
# 7             93.750000  75.000000  83.333333    60.000000
# 8             48.958333  78.333333  60.256410    60.000000
# 9             73.684211  70.000000  71.794872    60.000000
# 10            59.677419  61.666667  60.655738    60.000000
# 11            70.512821  91.666667  79.710145    60.000000
# 12            83.928571  78.333333  81.034483    60.000000
# 13            84.210526  80.000000  82.051282    60.000000
# 14            92.857143  86.666667  89.655172    60.000000
# ...

# %%
if y_true.shape[0]!=1020:
    raise Exception("ERROR!!!!")

# %%
accuracy = report_df.loc['accuracy']['precision']
precision = report_df.loc['macro avg']['precision']
recall = report_df.loc['macro avg']['recall']
f1_score = report_df.loc['macro avg']['f1-score']

# %%
print(precision, recall, accuracy, f1_score)
# Out:
# 78.70095707218822 77.74509803921569 77.74509803921569 77.10379218005082

# %%
print(str(round(precision, 1))+" "+str(round(recall, 1))+" "+str(round(accuracy, 1))+" "+str(round(f1_score, 1)))
# Out:
# 78.7 77.7 77.7 77.1
